# %% [markdown]
# # Computer Vision - P4

# %% [markdown]
# ## Delivery
#
# Your overall grading will be penalized if the following requirements are not fulfilled:
#
# - Implemented code should be commented exhaustively and in *English*.
#
# - The questions introduced in the exercises must be answered.
#
# - Add title to the figures to explain what is displayed.
#
# - Answers to questions also need to be in *English*.
#
# - Make sure to print and plot exactly what it is indicated. If a reference image is provided, your output is expected to be exactly the same unless instructed differently.
#
# - The deliverable of both parts must be a file named **P4_Student1_Student2.zip** that includes:
#     - The notebook P4_Student1_Student2.ipynb completed with the solutions to the exercises and their corresponding comments.
#     - All the images used in this notebook (upload the ones that were not provided)
#
# - It is required that your code can be run by us without need of any modification and without getting any errors.
#
# - Use packages and solutions that were covered in your class and tutorials. If you are unsure about using a particular package, you should seek clarification from your instructor to confirm whether it is allowed.
#
# - Please refrain from utilizing resources like ChatGPT to complete this lab assignment.
#
#
# **Deadline (Campus Virtual): November 28th, 23:00 h**

# %% [markdown]
# ==============================================================================================
# ## Descriptors extraction for object detection, based on template matching, ORB, and HOG
# ==============================================================================================
#
# The main topics of Laboratory 4 are:
#
#     4.1) SSD and Normalized Cross-correlation for template matching
#
#     4.2) HOG image descriptor for object (person) detection
#
#     4.3) Recognition by correspondance, based on feature extraction (ORB)

# %% [markdown]
# In order to complete this practicum, the following concepts need to be understood: template matching, feature localization (Harris, Censure), feature descriptor (HOG,ORB, Sift) methods.
#
# It is highly recommendable to structure the code in functions in order to reuse code for different tests and images and make it shorter and more readable. Specially the visualization commands should be encapsulated in separate functions.

# %% [markdown]
# ## 1 Template matching
#
# **1.1 (10 points)** Given the image 'einstein.png' and the template image 'eye.png', detect the location of the template in the image comparing the use of:
# - SSD distance (hint: norm() in numpy.linalg).
# - normalized cross-correlation (hint: match_template() of skimage.feature).
#
# Don't forget to normalize the images (having pixel values between [0,1]) before comparing them.

# %%
# Your solution here

# %% [markdown]
# Create a **function** for template matching applying SSD distance and normalized cross-correlation and display the results in the following format:
#
# <img src="images/tm.png" width="800" height="400">
#
# **Use titles in all figures to understand what is being displayed.**
#
# Note: the decision of threshold for SSD distance and normalized cross-correlation will affect your results, try values that get you as close to the shown result as possible but we understand you might not get exactly the same outcome.

# %%
# Your solution here

# %% [markdown]
# **1.2 (5 points)** How does the result of the template matching change if the image changes its contrast (for example if you make it clearer or darker)?
#
# Similarly to the previous case, please, visualize the euclidean distance and normalized cross-correlation images as well as the binarized (thresholded) images in the two cases.
#
# **Note:** Use titles of the figures to explain what is displayed.

# %% [markdown]
# Read `einstein_br.png` and display the results of the template matching techniques used on 1.1 on this image, using `eye.png` as template:

# %%
# Your solution here

# %% [markdown]
# Print the minimum SSD and the maximum Normalized Cross-Correlation (NCC)

# %%
# Your solution here

# %% [markdown]
# **1.3 (5 points)** Read `einstein_mask.png` and display the results on this image using your previously coded function, using the `eye.png` template:

# %%
# Your solution here

# %% [markdown]
# Print the minimum SSD and the maximum NCC

# %%
# Your solution here

# %% [markdown]
# What are the distances between the template and the image around the eyes of the image?

# %%
# Your solution here

# %% [markdown]
# Comment the template matching process:
# * Is the algorithms affected by contrast changes in the image?
# * How do metrics (i.e. minimum euclidean distance and maximum NCC) change in all previous cases? Is there a big difference among these values?
# * What parameters it has and which measure for image comparisons works better.

# %%
# Your solution here

# %% [markdown]
# **1.4 (5 points)** How does the result of the template matching change if instead the template is the one that changes its contrast (for example if you make it clearer or darker)? To this purpose, use the `eye_br.png` template.

# %%
# Your solution here

# %% [markdown]
# Check how the result changes if the template is rotated.
#
# Visualize the template and its rotation by 2º, 5º, 10º, 15º and 20º. Obtain again the template matching using the Euclidean distance and normalized cross-correlation. Pick fixed values of thresholds that are well suited for the non rotated image.
#
# **Help:** use the function rotate() in skimage.transform

# %%
# Your solution here

# %% [markdown]
# Comment the template matching process:
# * Please, explain briefly the algorithm, including advantages and disadvantage
# * Is the algorithms affected by contrast changes in the tempate image?
# * What parameters it has and which measure for image comparisons works better.

# %%
# Your solution here

# %% [markdown]
# # 2 Histogram of Oriented Gradients
#
# In this section we will treat the following topic: HOG image descriptor. Application to person detection.
#
# The Histogram of Oriented Gradients (HOG) feature descriptor is classical image descriptor for object detection.
#
# Given the image `person_template.bmp` and the folder `/images/TestPersonImages/`, apply the HOG descriptor in order to detect where there is a person in the images. To this purpose, apply the "sliding window" technique. We use images from GRAZ 01 data from [INRIA datasets](http://pascal.inrialpes.fr/data/human/).

# %% [markdown]
# **2.1. (5 points)** Read the template (`person_template.bmp`), obtain its HOG descriptor (with the optimal parameters) and visualize it.
#
# Help: the HOG detector function is in the skimage.feature library ([Help](http://scikit-image.org/docs/dev/auto_examples/features_detection/plot_hog.html#sphx-glr-auto-examples-features-detection-plot-hog-py)).
#
# Obtain 2 versions of the HOG descriptor:
# - With the default parameters.
# - Then with 4x4 pixels per cell and 2x2 cells per block and orientations set to 8
#
# Visualize the original image, the default values HOG descriptor and the defined parameters HOG descriptor in a 1x3 grid of images.

# %%
# Your solution here

# %% [markdown]
# Print and explain the number of feature resulting on the default parameters HOG descriptor (4536). Break this number down, starting from the original image size.

# %%
# Your solution here

# %% [markdown]
# **2.2. (15 points)** Apply the HOG descriptor on the complete set of images for person detection.
#
# a) Read images from the folder "TestPersonImages", slide a window on each image, obtain the HOG descriptor and compare to the HOG descriptor of the person template.
#
# b) Visualize the location in the image that is the most similar to the person template using the distance between the template and test image descriptors.
#
# Display the results of every person detection following this format:
#
# <img src="images/hog.png" width="400" height="200">

# %%
# Your solution here

# %% [markdown]
# Count on how many images were the persons detected correctly and discuss the failures.
# What do you think can be the reasons for the failures?

# %%
# Your solution here

# %% [markdown]
# Test several values of the parameters (``orientations``, ``pixels_per_cell``, ``cells_per_block``) to show which are the optimal values for the person detection problem. Note: since you are testing several values and not the whole universe, this question might have different solutions, make sure to try several to at least be directionally correct

# %%
# Your solution here

# %% [markdown]
# Comment the object detection process:
# * Please, explain briefly the algorithm, including advantages and disadvantage
# * Do you see any advantages of the HOG-based object detector compared to the template-based object detection? (The answer should be up to 10-15 lines).

# %%
# Your solution here

# %% [markdown]
# # 3 ORB feature detector and binary descriptor
#
# Let us consider the problem of feature extraction that contains two subproblems:
# - feature location,
# - image feature description.
#
# Let us focus on ORB, an approximation of SIFT method, and analyse if ORB is  scale and rotation invariant, a property that is very important for real-time applications.
#
# **Hint:** `ORB` is a function within the module `skimage.feature`
#
# **Help**: We suggest to have a look at the [ORB example](http://scikit-image.org/docs/dev/auto_examples/features_detection/plot_orb.html) how to compute the ORB descriptors and find the descriptors match. You can use the function match_descriptors from `skimage.feature` module in order to compute and show the similar detected descriptors of the given images.

# %% [markdown]
# **3.1 (10 points)** First, detect the censure in the image `starbucks4.jpg`. Analyze and discuss the effect of different values of the parameters in censure function. (this is a separate funcion from ORB)

# %%
# This solution was made, following the tutorial example -> https://scikit-image.org/docs/dev/auto_examples/features_detection/plot_orb.html
from skimage import io, transform
from skimage.feature import match_descriptors, ORB, plot_matches
from skimage.color import rgb2gray
import matplotlib.pyplot as plt

# Load the image
image_path = "./images/starbucks4.jpg"
starbucks = io.imread(image_path)

# Convert the image to grayscale
img1 = rgb2gray(starbucks)

# Rotate the image by 180 degrees to create a transformed version
img2 = transform.rotate(img1, 180)

# Apply an affine transformation to create another transformed version
tform = transform.AffineTransform(scale=(1.3, 1.1), rotation=0.5, translation=(0, -200))
img3 = transform.warp(img1, tform)

# Initialize the ORB descriptor extractor with 200 keypoints
descriptor_extractor = ORB(n_keypoints=200)

# Detect and extract keypoints and descriptors for the original image
descriptor_extractor.detect_and_extract(img1)
keypoints1 = descriptor_extractor.keypoints
descriptors1 = descriptor_extractor.descriptors

# Detect and extract keypoints and descriptors for the rotated image
descriptor_extractor.detect_and_extract(img2)
keypoints2 = descriptor_extractor.keypoints
descriptors2 = descriptor_extractor.descriptors

# Detect and extract keypoints and descriptors for the transformed image
descriptor_extractor.detect_and_extract(img3)
keypoints3 = descriptor_extractor.keypoints
descriptors3 = descriptor_extractor.descriptors

# Match descriptors between the original and rotated images
matches12 = match_descriptors(descriptors1, descriptors2, cross_check=True)

# Match descriptors between the original and transformed images
matches13 = match_descriptors(descriptors1, descriptors3, cross_check=True)

# Create subplots for visualization
fig, ax = plt.subplots(nrows=2, ncols=1)

# Display the matches between the original and rotated images
plt.gray()
plot_matches(ax[0], img1, img2, keypoints1, keypoints2, matches12)
ax[0].axis('off')
ax[0].set_title("Original Image vs. Transformed Image")

# Display the matches between the original and transformed images
plot_matches(ax[1], img1, img3, keypoints1, keypoints3, matches13)
ax[1].axis('off')
ax[1].set_title("Original Image vs. Transformed Image")

# Show the plots
plt.show()

# %% [markdown]
# **3.2 (10 points)** Detect the correspondences between the model image `starbucks.jpg` with the scene image `starbucks4.jpg`. You can adapt the code from the [ORB example](http://scikit-image.org/docs/dev/auto_examples/features_detection/plot_orb.html).
#
# Define a function get_ORB implementing the algorithm in order to be able to apply it on different images. Comment the code in detail.
#
# **Hint: If the function plot_matches() gives you an error you can use the plot_matches_aux() at the end of this file.**
#
# Analyze and discuss the effect of different values of the parameter `max_ratio` in the match_descriptors function.

# %%
from skimage import transform, feature, color, io
from skimage.feature import match_descriptors, ORB, plot_matches
import matplotlib.pyplot as plt

# this is an auxiliar function, we used to develop the solution
def get_ORB_aux(image1, image2, max_ratio=0.85, n_keypoints=200):
    """
    Perform ORB feature detection and matching between two images.

    Parameters:
    - image1: The first input image.
    - image2: The second input image.
    - max_ratio: Maximum ratio for the Lowe's ratio test in match_descriptors.
    - n_keypoints: Number of keypoints to detect using ORB.

    Returns:
    - keypoints1, keypoints2, matches: Keypoints and matches between the two images.
    """
    # Convert images to grayscale
    img1 = color.rgb2gray(image1)
    img2 = color.rgb2gray(image2)

    # Initialize ORB descriptor extractor
    descriptor_extractor = ORB(n_keypoints=n_keypoints)

    # Detect and extract keypoints and descriptors for the first image
    descriptor_extractor.detect_and_extract(img1)
    keypoints1 = descriptor_extractor.keypoints
    descriptors1 = descriptor_extractor.descriptors

    # Detect and extract keypoints and descriptors for the second image
    descriptor_extractor.detect_and_extract(img2)
    keypoints2 = descriptor_extractor.keypoints
    descriptors2 = descriptor_extractor.descriptors

    # Match descriptors between the two images
    matches = match_descriptors(descriptors1, descriptors2, cross_check=True, max_ratio=max_ratio)

    return keypoints1, keypoints2, matches

# Load the images
image_path1 = "./images/starbucks.jpg"
image_path2 = "./images/starbucks4.jpg"
starbucks_original = io.imread(image_path1)
starbucks_scene = io.imread(image_path2)

# Get ORB keypoints and matches
keypoints_model, keypoints_scene, matches = get_ORB_aux(starbucks_original, starbucks_scene)

# Visualize matches
fig, ax = plt.subplots()
plot_matches(ax, starbucks_original, starbucks_scene, keypoints_model, keypoints_scene, matches)
ax.axis('off')
ax.set_title("Original and Scene Image correspondences")
plt.show()

# %% [markdown]
# ANSWER: If we "modify" the 'max_ratio' parameter, we can observe how it impacts the final number of quality matches. If we put a 1 value, it seems that there are so many matches, less than 0.7 seem to not show any matches. So in our opinion a value between 0.7 to 1 is the way to go.

# %% [markdown]
# Repeate the experiment comparing the `starbucks.jpg` image as a model, and showing its matches to all Starbucks images, sorting them based on their similarity to the model. Comment when does the algorithm work better.

# %%
from skimage import transform, feature, color, io
from skimage.feature import match_descriptors, ORB, plot_matches
import matplotlib.pyplot as plt

def get_ORB_aux(image1, image2, max_ratio=0.85, n_keypoints=200):
    """
    Perform ORB feature detection and matching between two images.

    Parameters:
    - image1: The first input image.
    - image2: The second input image.
    - max_ratio: Maximum ratio for the Lowe's ratio test in match_descriptors.
    - n_keypoints: Number of keypoints to detect using ORB.

    Returns:
    - keypoints1, keypoints2, matches: Keypoints and matches between the two images.
    """
    # Convert images to grayscale
    img1 = color.rgb2gray(image1)
    img2 = color.rgb2gray(image2)

    # Initialize ORB descriptor extractor
    descriptor_extractor = ORB(n_keypoints=n_keypoints)

    # Detect and extract keypoints and descriptors for the first image
    descriptor_extractor.detect_and_extract(img1)
    keypoints1 = descriptor_extractor.keypoints
    descriptors1 = descriptor_extractor.descriptors

    # Detect and extract keypoints and descriptors for the second image
    descriptor_extractor.detect_and_extract(img2)
    keypoints2 = descriptor_extractor.keypoints
    descriptors2 = descriptor_extractor.descriptors

    # Match descriptors between the two images
    matches = match_descriptors(descriptors1, descriptors2, cross_check=True, max_ratio=max_ratio)

    return keypoints1, keypoints2, matches

# Starbucks Images
scene_images_paths = [
    "./images/starbucks.jpg",  # model image
    "./images/starbucks2.png",
    "./images/starbucks4.jpg",
    "./images/starbucks5.png",
    "./images/starbucks6.jpg",
    "./images/starbucksCup.jpg"
]

# Load the model image
model_image_path = scene_images_paths[0]
starbucks_model = io.imread(model_image_path)

# Initialize lists to store keypoints and matches for each scene image
all_keypoints = []
all_matches = []

# Get ORB keypoints and matches for each scene image
for scene_path in scene_images_paths[1:]:
    scene_image = io.imread(scene_path)

    # Get ORB keypoints and matches
    keypoints_model, keypoints_scene, matches = get_ORB_aux(starbucks_model, scene_image)

    # Store keypoints and matches
    all_keypoints.append(keypoints_scene)
    all_matches.append(matches)

# Visualize matches for each scene image
fig, axes = plt.subplots(nrows=len(scene_images_paths)-1, figsize=(10, 8))

for i, scene_path in enumerate(scene_images_paths[1:]):
    # Visualize matches using plt
    axes[i].imshow(starbucks_model, cmap='gray')
    axes[i].scatter(keypoints_model[:, 1], keypoints_model[:, 0], c='r', marker='o', s=10, label='Model keypoints')
    axes[i].imshow(io.imread(scene_path), cmap='gray', alpha=0.7)
    axes[i].scatter(all_keypoints[i][:, 1], all_keypoints[i][:, 0], c='b', marker='x', s=10, label='Scene keypoints')

    # Draw lines between matching keypoints
    for match in all_matches[i]:
        axes[i].plot([keypoints_model[match[0], 1], all_keypoints[i][match[1], 1]],
                     [keypoints_model[match[0], 0], all_keypoints[i][match[1], 0]], 'c')

    axes[i].axis('off')
    axes[i].set_title(f"Model vs. Scene Image {i+1}")

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-23-9ee4c6f77a78>:20: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   img2 = color.rgb2gray(image2)

# %% [markdown]
# ANSWER: The model seems to work better with "starbucks2, starbucks4 and starbucks5", the other ones are hard to detect due to different position / perspective.

# %% [markdown]
# **3.3 (5 points)** Repeat the experiment:
# - Changing the orientation of the model image by rotating it and comparing it with its original version. Help: you can use the rotate() function from skimage.transform
# - Change the scale and orientation of the scene image and compare it with the model image.

# %% [markdown]
# **Help:** To do so, you can use the function given below as example:
#
# ```
# import transform as tf
# rotationdegrees = 180
# img_rotated = tf.rotate(image2transform, rotationdegrees)
# ```
#
# or
#
# ```
# tform = tf.AffineTransform(scale=(1.2, 1.2), translation=(0, -100), rotation=0.5)
# img_transformed = tf.warp(image2transform, tform)
# ```

# %%
# Your solution here
from skimage import transform, feature, color, io
from skimage.feature import match_descriptors, ORB, plot_matches
import matplotlib.pyplot as plt

def get_ORB_aux(image1, image2, max_ratio=0.85, n_keypoints=200):
    """
    Perform ORB feature detection and matching between two images.

    Parameters:
    - image1: The first input image.
    - image2: The second input image.
    - max_ratio: Maximum ratio for the Lowe's ratio test in match_descriptors.
    - n_keypoints: Number of keypoints to detect using ORB.

    Returns:
    - keypoints1, keypoints2, matches: Keypoints and matches between the two images.
    """
    # Convert images to grayscale
    img1 = color.rgb2gray(image1)
    img2 = color.rgb2gray(image2)

    # Initialize ORB descriptor extractor
    descriptor_extractor = ORB(n_keypoints=n_keypoints)

    # Detect and extract keypoints and descriptors for the first image
    descriptor_extractor.detect_and_extract(img1)
    keypoints1 = descriptor_extractor.keypoints
    descriptors1 = descriptor_extractor.descriptors

    # Detect and extract keypoints and descriptors for the second image
    descriptor_extractor.detect_and_extract(img2)
    keypoints2 = descriptor_extractor.keypoints
    descriptors2 = descriptor_extractor.descriptors

    # Match descriptors between the two images
    matches = match_descriptors(descriptors1, descriptors2, cross_check=True, max_ratio=max_ratio)

    return keypoints1, keypoints2, matches

# Load the images
model_image_path = "./images/starbucks.jpg"
scene_image_path = "./images/starbucks4.jpg"
starbucks_model = io.imread(model_image_path)
starbucks_scene = io.imread(scene_image_path)

# Experiment 1: Changing the orientation of the model image by rotating it
model_image_rotated = transform.rotate(starbucks_model, 45)  # Rotate by 45 degrees

# Experiment 2: Changing the scale and orientation of the scene image
tform = transform.AffineTransform(scale=(1.5, 1.5), rotation=30)
scene_image_transformed = transform.warp(starbucks_scene, tform)

# Get ORB keypoints and matches for each experiment
keypoints_model, keypoints_scene, matches = get_ORB_aux(starbucks_model, starbucks_scene)
keypoints_rotated, _, matches_rotated = get_ORB_aux(starbucks_model, model_image_rotated)
keypoints_transformed, _, matches_transformed = get_ORB_aux(starbucks_model, scene_image_transformed)

# Visualize matches for each experiment
fig, axes = plt.subplots(nrows=3, ncols=1, figsize=(10, 12))

# Experiment 1: Visualize matches for the rotated model image
axes[0].imshow(starbucks_model, cmap='gray')
axes[0].scatter(keypoints_model[:, 1], keypoints_model[:, 0], c='r', marker='o', s=10, label='Model keypoints')
axes[0].imshow(model_image_rotated, cmap='gray', alpha=0.7)
axes[0].scatter(keypoints_rotated[:, 1], keypoints_rotated[:, 0], c='b', marker='x', s=10, label='Rotated keypoints')

for match in matches_rotated:
    axes[0].plot([keypoints_model[match[0], 1], keypoints_rotated[match[1], 1]],
                 [keypoints_model[match[0], 0], keypoints_rotated[match[1], 0]], 'c')

axes[0].axis('off')
axes[0].set_title("Experiment 1: Rotated Model vs. Original Scene")
axes[0].legend()

# Experiment 2: Visualize matches for the transformed scene image
axes[1].imshow(starbucks_model, cmap='gray')
axes[1].scatter(keypoints_model[:, 1], keypoints_model[:, 0], c='r', marker='o', s=10, label='Model keypoints')
axes[1].imshow(scene_image_transformed, cmap='gray', alpha=0.7)
axes[1].scatter(keypoints_transformed[:, 1], keypoints_transformed[:, 0], c='b', marker='x', s=10, label='Transformed keypoints')

for match in matches_transformed:
    axes[1].plot([keypoints_model[match[0], 1], keypoints_transformed[match[1], 1]],
                 [keypoints_model[match[0], 0], keypoints_transformed[match[1], 0]], 'c')

axes[1].axis('off')
axes[1].set_title("Experiment 2: Transformed Scene vs. Original Model")
axes[1].legend()

# Original matches for comparison
axes[2].imshow(starbucks_model, cmap='gray')
axes[2].scatter(keypoints_model[:, 1], keypoints_model[:, 0], c='r', marker='o', s=10, label='Model keypoints')
axes[2].imshow(starbucks_scene, cmap='gray', alpha=0.7)
axes[2].scatter(keypoints_scene[:, 1], keypoints_scene[:, 0], c='b', marker='x', s=10, label='Scene keypoints')

for match in matches:
    axes[2].plot([keypoints_model[match[0], 1], keypoints_scene[match[1], 1]],
                 [keypoints_model[match[0], 0], keypoints_scene[match[1], 0]], 'c')

axes[2].axis('off')
axes[2].set_title("Original Matches")

plt.tight_layout()
plt.show()

# %% [markdown]
# **(Optional)** Repeat the experiment (3.1 to 3.3) with a new group of images. You could use Coca-Cola advertisements or from another famous brand, easily to find on internet.

# %%
# Your solution here
from skimage import transform, feature, color, io
from skimage.feature import match_descriptors, ORB, plot_matches
import matplotlib.pyplot as plt

# Define the paths to the Coca-Cola images
model_image_path = "./images/coca_cola_original.png"
scene_images_paths = [
    "./images/coca_cola_original.png",  # model image
    "./images/coca_cola2.png",
    "./images/coca_cola3.png",
    "./images/coca_cola4.png"
]

# Load the model image
model_image = io.imread(model_image_path)

# Initialize lists to store keypoints and matches for each scene image
all_keypoints = []
all_matches = []

# Get ORB keypoints and matches for each scene image
for scene_path in scene_images_paths[1:]:
    scene_image = io.imread(scene_path)

    # Get ORB keypoints and matches
    keypoints_model, keypoints_scene, matches = get_ORB_aux(model_image, scene_image)

    # Store keypoints and matches
    all_keypoints.append(keypoints_scene)
    all_matches.append(matches)

# Visualize matches for each scene image
fig, axes = plt.subplots(nrows=len(scene_images_paths)-1, figsize=(10, 8))

for i, scene_path in enumerate(scene_images_paths[1:]):
    # Visualize matches using plt
    axes[i].imshow(model_image, cmap='gray')
    axes[i].scatter(keypoints_model[:, 1], keypoints_model[:, 0], c='r', marker='o', s=10, label='Model keypoints')
    axes[i].imshow(io.imread(scene_path), cmap='gray', alpha=0.7)
    axes[i].scatter(all_keypoints[i][:, 1], all_keypoints[i][:, 0], c='b', marker='x', s=10, label='Scene keypoints')

    # Draw lines between matching keypoints
    for match in all_matches[i]:
        axes[i].plot([keypoints_model[match[0], 1], all_keypoints[i][match[1], 1]],
                     [keypoints_model[match[0], 0], all_keypoints[i][match[1], 0]], 'c')

    axes[i].axis('off')
    axes[i].set_title(f"Model vs. Scene Image {i+1}")

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-24-82b20b2b6ea4>:20: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   img1 = color.rgb2gray(image1)
# <ipython-input-24-82b20b2b6ea4>:21: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   img2 = color.rgb2gray(image2)

# %% [markdown]
# **3.4 (5 points)** Analysis of the applied techniques and results
#
# - What are the advantages of the ORB object detection with respect to the HOG and template object detector?
#
# - What would happen if you analyse an image that does not contain the Starbucks logo?
#
# - Could you think of ways of defining a quality measure for the correspondance between two images? (no need of implementing it)

# %% [markdown]
# ANSWER:
#
# **What are the advantages of the ORB object detection with respect to the HOG and template object detector?**
#
# Works Well in Different Sizes and Angles: ORB can recognize objects even if they're a bit bigger, smaller, or tilted.
#
# Fast Enough for Quick Responses: ORB is speedy, making it suitable for applications that need quick, real-time responses.
#
# Saves Memory and Processes Quickly: ORB uses a clever way to describe objects that saves memory and makes the processing faster compared to HOG.
#
# Can Identify Objects More Clearly: ORB's way of describing objects helps in recognizing them more accurately and uniquely.
#
#
# **What would happen if you analyse an image that does not contain the Starbucks logo?**
#
# The matching step, won't find any significant keypoints between the two given models, now it depends to the template object detector... if it's to specific may not find any matches, but if it's more "general" may find some matches.
#
# **Could you think of ways of defining a quality measure for the correspondance between two images? (no need of implementing it)**
#
# Number of Good Matches: Check how many reliable matches there are between the two images. More good matches usually mean better correspondence.
#
# Consistency Across Different Views: See if the matches stay consistent when you look at the same scene from different angles. Reliable matches should be consistent from various viewpoints.
#
# Overlap Quality: Look at how well the matched areas overlap. If they align nicely, it's a sign of good correspondence.

# %% [markdown]
# # 4. SIFT
#
# **4.1 (5 points)** Now use SIFT to the same problem statement as 3.2 exercise, make sure to show the results with all starbucks images provided. For now, you can use the default parameters of SIFT.
# * Compare the results and the running time of both algortihms.
# * Which one works best on this case?

# %%
pip install opencv-python --upgrade

# %%
import cv2
from skimage import color, io
from skimage.feature import match_descriptors
import matplotlib.pyplot as plt

def get_SIFT_aux(image1, image2, n_features=200):
    """
    Perform SIFT feature detection and matching between two images.

    Parameters:
    - image1: The first input image.
    - image2: The second input image.
    - n_features: Number of keypoints to detect using SIFT.

    Returns:
    - keypoints1, keypoints2, matches: Keypoints and matches between the two images.
    """
    # Convert images to grayscale
    img1 = color.rgb2gray(image1)
    img2 = color.rgb2gray(image2)

    # Ensure the images are of type 'uint8' before passing to SIFT
    img1 = (img1 * 255).astype('uint8')
    img2 = (img2 * 255).astype('uint8')

    sift = cv2.SIFT_create(nfeatures = n_features) # DEFAULT PARAMETERS

    # Detect and compute keypoints and descriptors for the first image
    keypoints1, descriptors1 = sift.detectAndCompute(img1, None)

    # Detect and compute keypoints and descriptors for the second image
    keypoints2, descriptors2 = sift.detectAndCompute(img2, None)

    # Match descriptors between the two images
    matches = match_descriptors(descriptors1, descriptors2, cross_check=True)

    # Convert keypoints to arrays
    keypoints1 = cv2.KeyPoint_convert(keypoints1)
    keypoints2 = cv2.KeyPoint_convert(keypoints2)

    return keypoints1, keypoints2, matches

# Starbucks Images
scene_images_paths = [
    "./images/starbucks.jpg",  # model image
    "./images/starbucks2.png",
    "./images/starbucks4.jpg",
    "./images/starbucks5.png",
    "./images/starbucks6.jpg",
    "./images/starbucksCup.jpg"
]

# Load the model image
model_image_path = scene_images_paths[0]
starbucks_model = io.imread(model_image_path)

# Initialize lists to store keypoints and matches for each scene image
all_keypoints = []
all_matches = []

# Get SIFT keypoints and matches for each scene image
for scene_path in scene_images_paths[1:]:
    scene_image = io.imread(scene_path)

    # Get SIFT keypoints and matches
    keypoints_model, keypoints_scene, matches = get_SIFT_aux(starbucks_model, scene_image)

    # Store keypoints and matches
    all_keypoints.append(keypoints_scene)
    all_matches.append(matches)

# Visualize matches for each scene image
fig, axes = plt.subplots(nrows=len(scene_images_paths)-1, figsize=(10, 8))

for i, scene_path in enumerate(scene_images_paths[1:]):
    # Visualize matches using plt
    axes[i].imshow(starbucks_model, cmap='gray')
    axes[i].scatter(keypoints_model[:, 1], keypoints_model[:, 0], c='r', marker='o', s=10, label='Model keypoints')
    axes[i].imshow(io.imread(scene_path), cmap='gray', alpha=0.7)
    axes[i].scatter(all_keypoints[i][:, 1], all_keypoints[i][:, 0], c='b', marker='x', s=10, label='Scene keypoints')

    # Draw lines between matching keypoints
    for match in all_matches[i]:
        axes[i].plot([keypoints_model[match[0], 1], all_keypoints[i][match[1], 1]],
                     [keypoints_model[match[0], 0], all_keypoints[i][match[1], 0]], 'c')

    axes[i].axis('off')
    axes[i].set_title(f"Model vs. Scene Image {i+1}")

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-26-6db9ce88392e>:20: FutureWarning: Non RGB image conversion is now deprecated. For RGBA images, please use rgb2gray(rgba2rgb(rgb)) instead. In version 0.19, a ValueError will be raised if input image last dimension length is not 3.
#   img2 = color.rgb2gray(image2)

# %% [markdown]
# **4.2 (10 points)** Analyze the different SIFT parameters. Try and show the results for at least 3 different combination of parameters for starbucks4.jpg image against starbucks model image.
#
# * What are their effect?
# * How do they compare to ORB parameters?
# * Which algorithm is more suitable for images with rotation? And for images that have been rescaled, which one is more effective?
# * When it comes to changes in image intensity, which algorithm performs better, ORB or SIFT?

# %%
import cv2
from skimage import color, io
from skimage.feature import match_descriptors
import matplotlib.pyplot as plt

#ANALIZING DIFFERENTS PARAMETERS
def get_SIFT_aux(image1, image2, n_features=200, contrast_threshold=0.02, edge_threshold=10, sigma=1.6):
    """
    Perform SIFT feature detection and matching between two images.

    Parameters:
    - image1: The first input image.
    - image2: The second input image.
    - n_features: Number of keypoints to detect using SIFT.
    - contrast_threshold: Threshold to filter out keypoints based on local contrast.
    - edge_threshold: Threshold to filter out keypoints based on edge response.
    - sigma: Standard deviation of the Gaussian smoothing applied to the input image.

    Returns:
    - keypoints1, keypoints2, matches: Keypoints and matches between the two images.
    """
    # Convert images to grayscale
    img1 = color.rgb2gray(image1)
    img2 = color.rgb2gray(image2)

    # Ensure the images are of type 'uint8' before passing to SIFT
    img1 = (img1 * 255).astype('uint8')
    img2 = (img2 * 255).astype('uint8')
    
    #ANALIZING DIFFERENTS PARAMETERS
    sift = cv2.SIFT_create(nfeatures=n_features, contrastThreshold=contrast_threshold,
                           edgeThreshold=edge_threshold, sigma=sigma)

    # Detect and compute keypoints and descriptors for the first image
    keypoints1, descriptors1 = sift.detectAndCompute(img1, None)

    # Detect and compute keypoints and descriptors for the second image
    keypoints2, descriptors2 = sift.detectAndCompute(img2, None)

    # Match descriptors between the two images
    matches = match_descriptors(descriptors1, descriptors2, cross_check=True)

    # Convert keypoints to arrays
    keypoints1 = cv2.KeyPoint_convert(keypoints1)
    keypoints2 = cv2.KeyPoint_convert(keypoints2)

    return keypoints1, keypoints2, matches

# Starbucks Images
model_image_path = "./images/starbucks.jpg"
scene_image_path = "./images/starbucks4.jpg"

# Load the images
starbucks_model = io.imread(model_image_path)
starbucks_scene = io.imread(scene_image_path)

# Experiment with different SIFT parameters
for i, (contrast_threshold, edge_threshold, sigma) in enumerate([(0.02, 10, 1.6), (0.04, 15, 1.6), (0.02, 10, 2.0)]):
    # Get SIFT keypoints and matches
    keypoints_model, keypoints_scene, matches = get_SIFT_aux(starbucks_model, starbucks_scene,
                                                             contrast_threshold=contrast_threshold,
                                                             edge_threshold=edge_threshold,
                                                             sigma=sigma)

    # Visualize matches using plt
    plt.figure(figsize=(10, 8))
    plt.imshow(starbucks_model, cmap='gray')
    plt.scatter(keypoints_model[:, 1], keypoints_model[:, 0], c='r', marker='o', s=10, label='Model keypoints')
    plt.imshow(starbucks_scene, cmap='gray', alpha=0.7)
    plt.scatter(keypoints_scene[:, 1], keypoints_scene[:, 0], c='b', marker='x', s=10, label='Scene keypoints')

    # Draw lines between matching keypoints
    for match in matches:
        plt.plot([keypoints_model[match[0], 1], keypoints_scene[match[1], 1]],
                 [keypoints_model[match[0], 0], keypoints_scene[match[1], 0]], 'c')

    plt.axis('off')
    plt.title(f"SIFT Parameters Experiment {i+1}")
    plt.show()

# %% [markdown]
# **ANSWER**
#
# **What are their effect?**
#
# SIFT:
#
# Number of Features (n_features): Higher values increase keypoints, potentially improving matching but also increasing computation.
# Contrast Threshold: Controls the minimum local contrast for keypoint detection.
# Edge Threshold: Filters keypoints based on edge response.
# Sigma (sigma): Standard deviation for Gaussian smoothing, affecting noise and keypoint detection.
#
# ORB:
#
# Number of Keypoints (n_keypoints): Directly controls the number of keypoints.
# Other Parameters: ORB has fewer explicit parameters for fine-tuning.
#
#
# **How do they compare to ORB parameters?**
#
# Number of Keypoints:
#
# SIFT uses n_features for control, while ORB has a direct n_keypoints parameter.
# Rotation:
#
# Both SIFT and ORB are invariant to rotation.
# Rescaling:
#
# SIFT is generally more effective for handling changes in scale.
# Changes in Image Intensity:
#
# SIFT is often more robust to changes in illumination and intensity.
#
#
# **Which algorithm is more suitable for images with rotation? And for images that have been rescaled, which one is more effective?**
#
# Rotation:
#
# Both SIFT and ORB are suitable for images with rotation.
# Rescaling:
#
# SIFT is generally more effective for images that have been rescaled.
#
#
#
# **When it comes to changes in image intensity, which algorithm performs better, ORB or SIFT?**
#
# SIFT is generally more robust to changes in image intensity compared to ORB.

# %% [markdown]
# **4.3 (10 points)** Can we build an image classifier using the SIFT algorithm? Start by uploading the images from the folder `matches_SIFT`, then use the SIFT algorithm to find the most similar pairs (use the following parameters for this: max_ratio=0.8, upsampling=2, n_octaves=8, n_scales=3). To compare all the images, we'll need to establish a metric. We suggest to use the number of matches between images.
#
# Show your results (SIFT result image matches and print the similarity only for the most similar image for each of the 6 images provided). Rescale the images to see the matches between images.
#
# Answer the following:
# * Is the algorithm failing to find accurate matches (similar images) for some cases? If so, why do you think this is happening? You can assume that a good results is that eiffel tower images match between them and so on.
#
# Here is an example of the expected results for ciudad_ciencias_1.jpg (you also have to print the similarity metric result):
#
# <img src="images/example_city_of_arts.png" width="400" height="300">

# %%
# HELPFUL RESOURCE: https://www.analyticsvidhya.com/blog/2019/10/detailed-guide-powerful-sift-technique-image-matching-python/

import os
import cv2
import matplotlib.pyplot as plt

def sift_feature_matching(img1_path, img2_path):
    # Extract file names from paths
    img1_name = os.path.basename(img1_path)
    img2_name = os.path.basename(img2_path)

    # Read images
    img1 = cv2.imread(img1_path)
    img2 = cv2.imread(img2_path)

    # Convert images to grayscale
    gray1 = cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
    gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

    # SIFT
    sift = cv2.SIFT_create()

    # Detect and compute keypoints and descriptors
    keypoints_1, descriptors_1 = sift.detectAndCompute(gray1, None)
    keypoints_2, descriptors_2 = sift.detectAndCompute(gray2, None)

    # Feature matching using BFMatcher
    bf = cv2.BFMatcher()
    matches = bf.match(descriptors_1, descriptors_2)

    # Sort matches based on their distances
    matches = sorted(matches, key=lambda x: x.distance)

    # Print similarity metric (number of matches) with file names only
    print(f"Similarity Metric for {img1_name} vs. {img2_name}: {len(matches)} matches")

    # Draw the first 50 matches
    img_matches = cv2.drawMatches(img1, keypoints_1, img2, keypoints_2, matches[:50], None, flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)

    # Display the matches
    plt.imshow(img_matches)
    plt.title(f"Feature Matching: {img1_name} vs. {img2_name}")
    plt.axis('off')
    plt.show()

# List of image paths
image_paths = [
    "./images/matches_SIFT/ciudad_ciencias_1.jpg",
    "./images/matches_SIFT/ciudad_ciencias_2.jpg",
    "./images/matches_SIFT/eiffel_tower1.jpg",
    "./images/matches_SIFT/eiffel_tower2.jpg",
    "./images/matches_SIFT/ontario1.jpg",
    "./images/matches_SIFT/ontario2.jpeg"
]

# Perform feature matching for each pair of images
for i in range(0, len(image_paths), 2):
    sift_feature_matching(image_paths[i], image_paths[i + 1])
# Out:
# Similarity Metric for ciudad_ciencias_1.jpg vs. ciudad_ciencias_2.jpg: 11760 matches
# Similarity Metric for eiffel_tower1.jpg vs. eiffel_tower2.jpg: 3646 matches
# Similarity Metric for ontario1.jpg vs. ontario2.jpeg: 3927 matches

# %% [markdown]
# ### Appendix

# %%
# In case the plot_matches() function gives you some problems, you can use the following one:

from skimage.util import img_as_float
import numpy as np

def plot_matches_aux(ax, image1, image2, keypoints1, keypoints2, matches,
                 keypoints_color='k', matches_color=None, only_matches=False):
    """Plot matched features.
    Parameters
    ----------
    ax : matplotlib.axes.Axes
        Matches and image are drawn in this ax.
    image1 : (N, M [, 3]) array
        First grayscale or color image.
    image2 : (N, M [, 3]) array
        Second grayscale or color image.
    keypoints1 : (K1, 2) array
        First keypoint coordinates as ``(row, col)``.
    keypoints2 : (K2, 2) array
        Second keypoint coordinates as ``(row, col)``.
    matches : (Q, 2) array
        Indices of corresponding matches in first and second set of
        descriptors, where ``matches[:, 0]`` denote the indices in the first
        and ``matches[:, 1]`` the indices in the second set of descriptors.
    keypoints_color : matplotlib color, optional
        Color for keypoint locations.
    matches_color : matplotlib color, optional
        Color for lines which connect keypoint matches. By default the
        color is chosen randomly.
    only_matches : bool, optional
        Whether to only plot matches and not plot the keypoint locations.
    """

    image1 = img_as_float(image1)
    image2 = img_as_float(image2)

    new_shape1 = list(image1.shape)
    new_shape2 = list(image2.shape)

    if image1.shape[0] < image2.shape[0]:
        new_shape1[0] = image2.shape[0]
    elif image1.shape[0] > image2.shape[0]:
        new_shape2[0] = image1.shape[0]

    if image1.shape[1] < image2.shape[1]:
        new_shape1[1] = image2.shape[1]
    elif image1.shape[1] > image2.shape[1]:
        new_shape2[1] = image1.shape[1]

    if new_shape1 != image1.shape:
        new_image1 = np.zeros(new_shape1, dtype=image1.dtype)
        new_image1[:image1.shape[0], :image1.shape[1]] = image1
        image1 = new_image1

    if new_shape2 != image2.shape:
        new_image2 = np.zeros(new_shape2, dtype=image2.dtype)
        new_image2[:image2.shape[0], :image2.shape[1]] = image2
        image2 = new_image2

    image = np.concatenate([image1, image2], axis=1)

    offset = image1.shape

    if not only_matches:
        ax.scatter(keypoints1[:, 1], keypoints1[:, 0],
                   facecolors='none', edgecolors=keypoints_color)
        ax.scatter(keypoints2[:, 1] + offset[1], keypoints2[:, 0],
                   facecolors='none', edgecolors=keypoints_color)

    ax.imshow(image, interpolation='nearest', cmap='gray')
    ax.axis((0, 2 * offset[1], offset[0], 0))

    for i in range(matches.shape[0]):
        idx1 = matches[i, 0]
        idx2 = matches[i, 1]

        if matches_color is None:
            color = np.random.rand(3)
        else:
            color = matches_color

        ax.plot((keypoints1[idx1, 1], keypoints2[idx2, 1] + offset[1]),
                (keypoints1[idx1, 0], keypoints2[idx2, 0]),
                '-', color=color)
